# %% [markdown]
# <a href="https://colab.research.google.com/github/thasliya0404/class-activity/blob/main/xlsx_xml.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
employees = pd.read_excel('/content/employee.xlsx')
employees
# Out:
#   Unnamed: 0     Unnamed: 1   Unnamed: 2 Unnamed: 3 Unnamed: 4 Unnamed: 5
# 0     emp_id           name   department  hire_date     salary  full_time
# 1      E1001  Julia Roberts    Marketing      43171      72000       True
# 2      E1002   Ahmed Hassan  Engineering      43669      85000       True
# 3      E1003    Priya Singh           HR      43845      60000      False
# 4      E1004         Li Wei      Finance      43069      79000       True
# 5      E1005  Carlos Mendes        Sales      44326      67000       True

# %%
employees = pd.read_excel('/content/employee.xlsx',header=1)
employees
# Out:
#   emp_id           name   department  hire_date  salary  full_time
# 0  E1001  Julia Roberts    Marketing      43171   72000       True
# 1  E1002   Ahmed Hassan  Engineering      43669   85000       True
# 2  E1003    Priya Singh           HR      43845   60000      False
# 3  E1004         Li Wei      Finance      43069   79000       True
# 4  E1005  Carlos Mendes        Sales      44326   67000       True

# %%
data = pd.read_excel('/content/employee.xlsx',header=1,sheet_name='Sheet2')
data
# Out:
#   emp_id           name   department  hire_date  salary  full_time
# 0  E1001  Julia Roberts    Marketing      43171   72000       True
# 1  E1002   Ahmed Hassan  Engineering      43669   85000       True
# 2  E1003    Priya Singh           HR      43845   60000      False
# 3  E1004         Li Wei      Finance      43925   79000       True
# 4  E1005  Carlos Mendes        Sales      44326   67000       True

# %%
data = pd.read_excel('/content/employee.xlsx',header=1,sheet_name=None)
data
# Out:
# {'Sheet1':   emp_id           name   department  hire_date  salary  full_time
#  0  E1001  Julia Roberts    Marketing      43171   72000       True
#  1  E1002   Ahmed Hassan  Engineering      43669   85000       True
#  2  E1003    Priya Singh           HR      43845   60000      False
#  3  E1004         Li Wei      Finance      43069   79000       True
#  4  E1005  Carlos Mendes        Sales      44326   67000       True,
#  'Sheet2':   emp_id           name   department  hire_date  salary  full_time
#  0  E1001  Julia Roberts    Marketing      43171   72000       True
#  1  E1002   Ahmed Hassan  Engineering      43669   85000       True
#  2  E1003    Priya Singh           HR      43845   60000      False
#  3  E1004         Li Wei      Finance      43925   79000       True
#  4  E1005  Carlos Mendes        Sales      44326   67000       True}

# %%
xlsheets = pd.ExcelFile('/content/employee.xlsx')
xlsheets.sheet_names
# Out:
# ['Sheet1', 'Sheet2']

# %%
data['Sheet1']
# Out:
#   emp_id           name   department  hire_date  salary  full_time
# 0  E1001  Julia Roberts    Marketing      43171   72000       True
# 1  E1002   Ahmed Hassan  Engineering      43669   85000       True
# 2  E1003    Priya Singh           HR      43845   60000      False
# 3  E1004         Li Wei      Finance      43069   79000       True
# 4  E1005  Carlos Mendes        Sales      44326   67000       True

# %%
data['Sheet2']
# Out:
#   emp_id           name   department  hire_date  salary  full_time
# 0  E1001  Julia Roberts    Marketing      43171   72000       True
# 1  E1002   Ahmed Hassan  Engineering      43669   85000       True
# 2  E1003    Priya Singh           HR      43845   60000      False
# 3  E1004         Li Wei      Finance      43925   79000       True
# 4  E1005  Carlos Mendes        Sales      44326   67000       True

# %%
data1 = data['Sheet1']
data2 = data['Sheet2']

# %%
data = pd.concat([data1, data2], ignore_index=True)
data
# Out:
#   emp_id           name   department  hire_date  salary  full_time
# 0  E1001  Julia Roberts    Marketing      43171   72000       True
# 1  E1002   Ahmed Hassan  Engineering      43669   85000       True
# 2  E1003    Priya Singh           HR      43845   60000      False
# 3  E1004         Li Wei      Finance      43069   79000       True
# 4  E1005  Carlos Mendes        Sales      44326   67000       True
# 5  E1001  Julia Roberts    Marketing      43171   72000       True
# 6  E1002   Ahmed Hassan  Engineering      43669   85000       True
# 7  E1003    Priya Singh           HR      43845   60000      False
# 8  E1004         Li Wei      Finance      43925   79000       True
# 9  E1005  Carlos Mendes        Sales      44326   67000       True

# %%
full_time_employees = data[data['full_time'] == True]
full_time_employees
# Out:
#   emp_id           name   department  hire_date  salary  full_time
# 0  E1001  Julia Roberts    Marketing      43171   72000       True
# 1  E1002   Ahmed Hassan  Engineering      43669   85000       True
# 3  E1004         Li Wei      Finance      43069   79000       True
# 4  E1005  Carlos Mendes        Sales      44326   67000       True
# 5  E1001  Julia Roberts    Marketing      43171   72000       True
# 6  E1002   Ahmed Hassan  Engineering      43669   85000       True
# 8  E1004         Li Wei      Finance      43925   79000       True
# 9  E1005  Carlos Mendes        Sales      44326   67000       True

# %%
mean_salary_by_department = data.groupby('department')['salary'].mean()
mean_salary_by_department
# Out:
# department
# Engineering    85000.0
# Finance        79000.0
# HR             60000.0
# Marketing      72000.0
# Sales          67000.0
# Name: salary, dtype: float64

# %%
mean_salary_by_department = data.groupby('department').salary.mean()
mean_salary_by_department
# Out:
# department
# Engineering    85000.0
# Finance        79000.0
# HR             60000.0
# Marketing      72000.0
# Sales          67000.0
# Name: salary, dtype: float64

# %%
data.to_excel('newdata_employee.xlsx',index=False)

# %%
newdata = pd.read_excel('/content/newdata_employee.xlsx')
newdata
# Out:
#   emp_id           name   department  hire_date  salary  full_time
# 0  E1001  Julia Roberts    Marketing      43171   72000       True
# 1  E1002   Ahmed Hassan  Engineering      43669   85000       True
# 2  E1003    Priya Singh           HR      43845   60000      False
# 3  E1004         Li Wei      Finance      43069   79000       True
# 4  E1005  Carlos Mendes        Sales      44326   67000       True
# 5  E1001  Julia Roberts    Marketing      43171   72000       True
# 6  E1002   Ahmed Hassan  Engineering      43669   85000       True
# 7  E1003    Priya Singh           HR      43845   60000      False
# 8  E1004         Li Wei      Finance      43925   79000       True
# 9  E1005  Carlos Mendes        Sales      44326   67000       True

# %%
weather = pd.read_csv('/content/weather.csv')
weather
# Out:
#          date station_id  temperature_c  humidity_pct  wind_speed_kmh  \
# 0  2025-07-01      WS100           29.5            65            12.4
# 1  2025-07-01      WS101           31.2            58             8.7
# 2  2025-07-01      WS102           28.9            72             5.2
# 3  2025-07-02      WS100           30.1            63            14.0
# 4  2025-07-02      WS101           32.0            55            10.1
# 5  2025-07-02      WS102           29.5            70             6.0
# 6  2025-07-03      WS100           28.0            68            11.3
# 7  2025-07-03      WS101           29.8            60             9.5
# 8  2025-07-03      WS102           27.7            75             4.8
#
#    precip_mm
# 0        0.0
# 1        0.0
# 2        1.3
# 3        0.0
# 4        0.0
# 5        0.8
# 6        2.5
# 7        0.0
# 8        3.1

# %%
#print days where temperature greater than 30
temperature_greater_than_30 = weather[weather['temperature_c']>30]
temperature_greater_than_30
# Out:
#          date station_id  temperature_c  humidity_pct  wind_speed_kmh  \
# 1  2025-07-01      WS101           31.2            58             8.7
# 3  2025-07-02      WS100           30.1            63            14.0
# 4  2025-07-02      WS101           32.0            55            10.1
#
#    precip_mm
# 1        0.0
# 3        0.0
# 4        0.0

# %%
#compute daily average humidity
avg_humidity = weather.groupby('date').humidity_pct.mean()
avg_humidity
# Out:
# date
# 2025-07-01    65.000000
# 2025-07-02    62.666667
# 2025-07-03    67.666667
# Name: humidity_pct, dtype: float64

# %% [markdown]
# **xml**
#
#
# tags <>
#
#
# starting <'catalog>
#
#
# closing tab # </'catalog>

# %%
library_catalog = pd.read_xml('/content/library_catalog.xml')
library_catalog
# Out:
#              isbn                    title           author            genre  \
# 0  978-0143127550              The Martian        Andy Weir  Science Fiction
# 1  978-0553386790  Thinking, Fast and Slow  Daniel Kahneman       Psychology
# 2  978-0062316097            The Alchemist     Paulo Coelho          Fiction
#
#   publish_date  price
# 0   2014-10-28   9.99
# 1   2013-04-02  12.50
# 2   2014-04-15   8.99

# %%
library_catalog1 = library_catalog['genre'].nunique()
library_catalog1
# Out:
# 3

# %% [markdown]
# **json**
#
#
# aps

# %%
movies = pd.read_json('/content/movies.json')
movies
# Out:
#   movie_id                     title  year                      genres  \
# 0    MV001                 Inception  2010            [Action, Sci‐Fi]
# 1    MV002           The Dark Knight  2008      [Action, Crime, Drama]
# 2    MV003              Interstellar  2014  [Adventure, Drama, Sci‐Fi]
# 3    MV004                The Matrix  1999            [Action, Sci‐Fi]
# 4    MV005                  Parasite  2019   [Comedy, Drama, Thriller]
# 5    MV006                 Gladiator  2000  [Action, Adventure, Drama]
# 6    MV007         Avengers: Endgame  2019  [Action, Adventure, Drama]
# 7    MV008  The Shawshank Redemption  1994                     [Drama]
# 8    MV009              Pulp Fiction  1994              [Crime, Drama]
# 9    MV010              Forrest Gump  1994            [Drama, Romance]
#
#    rating    votes
# 0     8.8  2100000
# 1     9.0  2300000
# 2     8.6  1500000
# 3     8.7  1700000
# 4     8.6   700000
# 5     8.5  1400000
# 6     8.4  1000000
# 7     9.3  2400000
# ...

# %%
#highest rated movie
highest_rated_movie = movies['rating'].max()
highest_rated_movie
# Out:
# 9.3

# %%
exploded_movies = movies.explode('genres',ignore_index=True)
exploded_movies
# Out:
#    movie_id                     title  year     genres  rating    votes
# 0     MV001                 Inception  2010     Action     8.8  2100000
# 1     MV001                 Inception  2010     Sci‐Fi     8.8  2100000
# 2     MV002           The Dark Knight  2008     Action     9.0  2300000
# 3     MV002           The Dark Knight  2008      Crime     9.0  2300000
# 4     MV002           The Dark Knight  2008      Drama     9.0  2300000
# 5     MV003              Interstellar  2014  Adventure     8.6  1500000
# 6     MV003              Interstellar  2014      Drama     8.6  1500000
# 7     MV003              Interstellar  2014     Sci‐Fi     8.6  1500000
# 8     MV004                The Matrix  1999     Action     8.7  1700000
# 9     MV004                The Matrix  1999     Sci‐Fi     8.7  1700000
# 10    MV005                  Parasite  2019     Comedy     8.6   700000
# 11    MV005                  Parasite  2019      Drama     8.6   700000
# ...

# %%
exploded_movies = movies.explode('genres')
exploded_movies
# Out:
#   movie_id                     title  year     genres  rating    votes
# 0    MV001                 Inception  2010     Action     8.8  2100000
# 0    MV001                 Inception  2010     Sci‐Fi     8.8  2100000
# 1    MV002           The Dark Knight  2008     Action     9.0  2300000
# 1    MV002           The Dark Knight  2008      Crime     9.0  2300000
# 1    MV002           The Dark Knight  2008      Drama     9.0  2300000
# 2    MV003              Interstellar  2014  Adventure     8.6  1500000
# 2    MV003              Interstellar  2014      Drama     8.6  1500000
# 2    MV003              Interstellar  2014     Sci‐Fi     8.6  1500000
# 3    MV004                The Matrix  1999     Action     8.7  1700000
# 3    MV004                The Matrix  1999     Sci‐Fi     8.7  1700000
# 4    MV005                  Parasite  2019     Comedy     8.6   700000
# 4    MV005                  Parasite  2019      Drama     8.6   700000
# ...

# %%
#avg rating by genre
avg_rating = exploded_movies.groupby('genres').rating.mean()
avg_rating
# Out:
# genres
# Action       8.6800
# Adventure    8.5000
# Comedy       8.6000
# Crime        8.9500
# Drama        8.7625
# Romance      8.8000
# Sci‐Fi       8.7000
# Thriller     8.6000
# Name: rating, dtype: float64

# %%
#count movies by year
movies_by_year = movies.groupby('year').size()
movies_by_year
# Out:
# year
# 1994    3
# 1999    1
# 2000    1
# 2008    1
# 2010    1
# 2014    1
# 2019    2
# dtype: int64

# %%
highest_rated_movie = movies[movies['rating'] == highest_rated_movie]['title']
highest_rated_movie
# Out:
# 7    The Shawshank Redemption
# Name: title, dtype: object

# %%
review = pd.read_html('/content/review.html')[0]
review
# Out:
#   review_id reviewer     restaurant  rating                         comment  \
# 0      R001    Alice  The Spice Hub     4.5   Great flavors but a bit loud.
# 1      R002      Bob    Sushi World     5.0    Fresh fish and perfect rice.
# 2      R003     Chen   Pasta Palace     4.0  Cozy place, generous portions.
#
#          date
# 0  2025-06-20
# 1  2025-06-22
# 2  2025-06-25

# %%
restaurent_rating_above = review[review['rating']>4.5]
restaurent_rating_above
# Out:
#   review_id reviewer   restaurant  rating                       comment  \
# 1      R002      Bob  Sushi World     5.0  Fresh fish and perfect rice.
#
#          date
# 1  2025-06-22

# %%
import requests
url = 'https://disease.sh/v3/covid-19/countries'
response = requests.get(url)
data = response.json()
data
# Out:
# [{'updated': 1757414676667,
#   'country': 'Afghanistan',
#   'countryInfo': {'_id': 4,
#    'iso2': 'AF',
#    'iso3': 'AFG',
#    'lat': 33,
#    'long': 65,
#    'flag': 'https://disease.sh/assets/img/flags/af.png'},
#   'cases': 234174,
#   'todayCases': 0,
#   'deaths': 7996,
#   'todayDeaths': 0,
#   'recovered': 211080,
#   'todayRecovered': 0,
#   'active': 15098,
#   'critical': 0,
#   'casesPerOneMillion': 5746,
#   'deathsPerOneMillion': 196,
#   'tests': 1390730,
#   'testsPerOneMillion': 34125,
#   'population': 40754388,
#   'continent': 'Asia',
#   'oneCasePerPeople': 174,
#   'oneDeathPerPeople': 5097,
#   'oneTestPerPeople': 29,
#   'activePerOneMillion': 370.46,
#   'recoveredPerOneMillion': 5179.32,
#   'criticalPerOneMillion': 0},
#  {'updated': 1757414676659,
#   'country': 'Albania',
#   'countryInfo': {'_id': 8,
#    'iso2': 'AL',
#    'iso3': 'ALB',
#    'lat': 41,
#    'long': 20,
#    'flag': 'https://disease.sh/assets/img/flags/al.png'},
# ...

# %%
covid_df = pd.DataFrame(data)
covid_df.head()
# Out:
#          updated      country  \
# 0  1757414676667  Afghanistan
# 1  1757414676659      Albania
# 2  1757414676663      Algeria
# 3  1757414676715      Andorra
# 4  1757414676689       Angola
#
#                                          countryInfo   cases  todayCases  \
# 0  {'_id': 4, 'iso2': 'AF', 'iso3': 'AFG', 'lat':...  234174           0
# 1  {'_id': 8, 'iso2': 'AL', 'iso3': 'ALB', 'lat':...  334863           0
# 2  {'_id': 12, 'iso2': 'DZ', 'iso3': 'DZA', 'lat'...  272010           0
# 3  {'_id': 20, 'iso2': 'AD', 'iso3': 'AND', 'lat'...   48015           0
# 4  {'_id': 24, 'iso2': 'AO', 'iso3': 'AGO', 'lat'...  107327           0
#
#    deaths  todayDeaths  recovered  todayRecovered  active  ...    tests  \
# 0    7996            0     211080               0   15098  ...  1390730
# 1    3605            0     330233               0    1025  ...  1941032
# 2    6881            0     183061               0   82068  ...   230960
# ...

# %%
covid_df.columns
# Out:
# Index(['updated', 'country', 'countryInfo', 'cases', 'todayCases', 'deaths',
#        'todayDeaths', 'recovered', 'todayRecovered', 'active', 'critical',
#        'casesPerOneMillion', 'deathsPerOneMillion', 'tests',
#        'testsPerOneMillion', 'population', 'continent', 'oneCasePerPeople',
#        'oneDeathPerPeople', 'oneTestPerPeople', 'activePerOneMillion',
#        'recoveredPerOneMillion', 'criticalPerOneMillion'],
#       dtype='object')

# %%
covid_df.to_excel('covid_countries_data.xlsx', index=False)
covid_countries = pd.read_excel('/content/covid_countries_data.xlsx')
covid_countries
# Out:
#            updated            country  \
# 0    1757414676667        Afghanistan
# 1    1757414676659            Albania
# 2    1757414676663            Algeria
# 3    1757414676715            Andorra
# 4    1757414676689             Angola
# ..             ...                ...
# 226  1757414676790  Wallis and Futuna
# 227  1757414676800     Western Sahara
# 228  1757414676770              Yemen
# 229  1757414676655             Zambia
# 230  1757414676665           Zimbabwe
#
#                                            countryInfo   cases  todayCases  \
# 0    {'_id': 4, 'iso2': 'AF', 'iso3': 'AFG', 'lat':...  234174           0
# 1    {'_id': 8, 'iso2': 'AL', 'iso3': 'ALB', 'lat':...  334863           0
# 2    {'_id': 12, 'iso2': 'DZ', 'iso3': 'DZA', 'lat'...  272010           0
# 3    {'_id': 20, 'iso2': 'AD', 'iso3': 'AND', 'lat'...   48015           0
# 4    {'_id': 24, 'iso2': 'AO', 'iso3': 'AGO', 'lat'...  107327           0
# ...

# %%
covid_df.columns
# Out:
# Index(['updated', 'country', 'countryInfo', 'cases', 'todayCases', 'deaths',
#        'todayDeaths', 'recovered', 'todayRecovered', 'active', 'critical',
#        'casesPerOneMillion', 'deathsPerOneMillion', 'tests',
#        'testsPerOneMillion', 'population', 'continent', 'oneCasePerPeople',
#        'oneDeathPerPeople', 'oneTestPerPeople', 'activePerOneMillion',
#        'recoveredPerOneMillion', 'criticalPerOneMillion'],
#       dtype='object')

# %%
necessary_columns = covid_df[['country','cases','deaths','recovered','active','critical','tests']]
display(necessary_columns)
# Out:
#                country   cases  deaths  recovered  active  critical    tests
# 0          Afghanistan  234174    7996     211080   15098         0  1390730
# 1              Albania  334863    3605     330233    1025         0  1941032
# 2              Algeria  272010    6881     183061   82068         0   230960
# 3              Andorra   48015     165          0   47850         0   249838
# 4               Angola  107327    1937     103419    1971         0  1499795
# ..                 ...     ...     ...        ...     ...       ...      ...
# 226  Wallis and Futuna    3550       8        438    3104         0    20508
# 227     Western Sahara      10       1          9       0         0        0
# 228              Yemen   11945    2159       9124     662         0   329592
# 229             Zambia  349304    4069     341316    3919         0  4112961
# 230           Zimbabwe  266359    5740     258888    1731        12  2525756
#
# [231 rows x 7 columns]

# %%
url = 'https://www.runnersworld.com/races-places/a20823734/these-are-the-worlds-fastest-marathoners-and-marathon-courses/'
runner = pd.read_html(url,header=0)
runner
# Out:
# [                       Runner Finish Time Pace/Mile        Marathon
#  0       Kelvin Kiptum (Kenya)     2:00:35    4:36.0   Chicago, 2023
#  1      Eliud Kipchoge (Kenya)     2:01:09    4:37.2    Berlin, 2022
#  2  Kenenisa Bekele (Ethiopia)     2:01:41    4:38.5    Berlin, 2019
#  3      Sisay Lemma (Ethiopia)     2:01:48    4:38.7  Valencia, 2023
#  4      Sabastian Sawe (Kenya)     2:02:05    4:39.4  Valencia, 2024
#  5      Benson Kipruto (Kenya)     2:02:16    4:39.8     Tokyo, 2024
#  6    Deresa Geleta (Ethiopia)     2:02:38    4:40.6  Valencia, 2024
#  7          John Korir (Kenya)     2:02:44    4:40.8   Chicago, 2024
#  8   Birhanu Legese (Ethiopia)     2:02:48    4:41.0    Berlin, 2019
#  9  Mosinet Geremew (Ethiopia)     2:02:55    4:41.3    London, 2019,
#                               Runner Finish Time Pace/Mile        Marathon
#  0          Ruth Chepngetich (Kenya)     2:09:56    4:57.4   Chicago, 2024
# ...

# %%
print(len(runner))
# Out:
# 8

# %%
print(type(runner))
# Out:
# <class 'list'>

# %% [markdown]
# data = pd.concat([data1, data2], ignore_index=True)

# %%
data1 = runner[0]
data2 = runner[1]
data3 = runner[2]
data4 = runner[3]
data5 = runner[4]
data6 = runner[5]
data7 = runner[6]
data8 = runner[7]

# %%
data = pd.concat([data1,data2,data3,data4,data5,data6,data7,data8],ignore_index=True)
data
# Out:
#                              Runner Finish Time Pace/Mile        Marathon
# 0             Kelvin Kiptum (Kenya)     2:00:35    4:36.0   Chicago, 2023
# 1            Eliud Kipchoge (Kenya)     2:01:09    4:37.2    Berlin, 2022
# 2        Kenenisa Bekele (Ethiopia)     2:01:41    4:38.5    Berlin, 2019
# 3            Sisay Lemma (Ethiopia)     2:01:48    4:38.7  Valencia, 2023
# 4            Sabastian Sawe (Kenya)     2:02:05    4:39.4  Valencia, 2024
# ..                              ...         ...       ...             ...
# 80  Paula Radcliffe (Great Britain)     2:17:18    5:14.2   Chicago, 2002
# 81  Paula Radcliffe (Great Britain)     2:15:25    5:09.9    London, 2003
# 82            Brigid Kosgei (Kenya)     2:14:04    5:06.8   Chicago, 2019
# 83         Tigist Assefa (Ethiopia)     2:11:53    5:01.8    Berlin, 2023
# 84         Ruth Chepngetich (Kenya)     2:09:56    4:47.4   Chicago, 2024
#
# [85 rows x 4 columns]

# %%
url = 'https://api.spacexdata.com/v4/rockets'
response = requests.get(url)
launch_data = response.json()
response
launch_data
# Out:
# [{'height': {'meters': 22.25, 'feet': 73},
#   'diameter': {'meters': 1.68, 'feet': 5.5},
#   'mass': {'kg': 30146, 'lb': 66460},
#   'first_stage': {'thrust_sea_level': {'kN': 420, 'lbf': 94000},
#    'thrust_vacuum': {'kN': 480, 'lbf': 110000},
#    'reusable': False,
#    'engines': 1,
#    'fuel_amount_tons': 44.3,
#    'burn_time_sec': 169},
#   'second_stage': {'thrust': {'kN': 31, 'lbf': 7000},
#    'payloads': {'composite_fairing': {'height': {'meters': 3.5, 'feet': 11.5},
#      'diameter': {'meters': 1.5, 'feet': 4.9}},
#     'option_1': 'composite fairing'},
#    'reusable': False,
#    'engines': 1,
#    'fuel_amount_tons': 3.38,
#    'burn_time_sec': 378},
#   'engines': {'isp': {'sea_level': 267, 'vacuum': 304},
#    'thrust_sea_level': {'kN': 420, 'lbf': 94000},
#    'thrust_vacuum': {'kN': 480, 'lbf': 110000},
#    'number': 1,
#    'type': 'merlin',
#    'version': '1C',
#    'layout': 'single',
#    'engine_loss_max': 0,
#    'propellant_1': 'liquid oxygen',
# ...

# %%
url  = 'https://api.spacexdata.com/v4/launches'
response = requests.get(url)
response
launch_data = response.json()
launch_data
df1 = pd.DataFrame(launch_data)
df1
# Out:
#                                               fairings  \
# 0    {'reused': False, 'recovery_attempt': False, '...
# 1    {'reused': False, 'recovery_attempt': False, '...
# 2    {'reused': False, 'recovery_attempt': False, '...
# 3    {'reused': False, 'recovery_attempt': False, '...
# 4    {'reused': False, 'recovery_attempt': False, '...
# ..                                                 ...
# 200  {'reused': None, 'recovery_attempt': None, 're...
# 201  {'reused': None, 'recovery_attempt': None, 're...
# 202  {'reused': None, 'recovery_attempt': None, 're...
# 203  {'reused': None, 'recovery_attempt': None, 're...
# 204  {'reused': None, 'recovery_attempt': None, 're...
#
#                                                  links  \
# 0    {'patch': {'small': 'https://images2.imgbox.co...
# 1    {'patch': {'small': 'https://images2.imgbox.co...
# 2    {'patch': {'small': 'https://images2.imgbox.co...
# 3    {'patch': {'small': 'https://images2.imgbox.co...
# ...

# %%
df1 = pd.DataFrame(launch_data)
df1
# Out:
#                                               fairings  \
# 0    {'reused': False, 'recovery_attempt': False, '...
# 1    {'reused': False, 'recovery_attempt': False, '...
# 2    {'reused': False, 'recovery_attempt': False, '...
# 3    {'reused': False, 'recovery_attempt': False, '...
# 4    {'reused': False, 'recovery_attempt': False, '...
# ..                                                 ...
# 200  {'reused': None, 'recovery_attempt': None, 're...
# 201  {'reused': None, 'recovery_attempt': None, 're...
# 202  {'reused': None, 'recovery_attempt': None, 're...
# 203  {'reused': None, 'recovery_attempt': None, 're...
# 204  {'reused': None, 'recovery_attempt': None, 're...
#
#                                                  links  \
# 0    {'patch': {'small': 'https://images2.imgbox.co...
# 1    {'patch': {'small': 'https://images2.imgbox.co...
# 2    {'patch': {'small': 'https://images2.imgbox.co...
# 3    {'patch': {'small': 'https://images2.imgbox.co...
# ...

# %%
df2 = pd.DataFrame(response)
df2
# Out:
#                                                       0
# 0     b'[{"fairings":{"reused":false,"recovery_attem...
# 1     b'mgbox.com/94/f2/NN6Ph45r_o.png","large":"htt...
# 2     b'll,"media":null,"recovery":null},"flickr":{"...
# 3     b'0a_00nJ_Y88","youtube_id":"0a_00nJ_Y88","art...
# 4     b',"wikipedia":"https://en.wikipedia.org/wiki/...
# ...                                                 ...
# 3401  b'ils":null,"crew":[],"ships":[],"capsules":[]...
# 3402  b'ght_number":203,"name":"O3b mPower 3.4","dat...
# 3403  b':00:00-05:00","date_precision":"month","upco...
# 3404  b'null,"landing_attempt":null,"landing_success...
# 3405  b'ibrary_id":null,"id":"6243ae7daf52800c6e9192...
#
# [3406 rows x 1 columns]

# %%
df1.columns
# Out:
# Index(['fairings', 'links', 'static_fire_date_utc', 'static_fire_date_unix',
#        'net', 'window', 'rocket', 'success', 'failures', 'details', 'crew',
#        'ships', 'capsules', 'payloads', 'launchpad', 'flight_number', 'name',
#        'date_utc', 'date_unix', 'date_local', 'date_precision', 'upcoming',
#        'cores', 'auto_update', 'tbd', 'launch_library_id', 'id'],
#       dtype='object')

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 205 entries, 0 to 204
# Data columns (total 27 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   fairings               169 non-null    object
#  1   links                  205 non-null    object
#  2   static_fire_date_utc   121 non-null    object
#  3   static_fire_date_unix  121 non-null    float64
#  4   net                    205 non-null    bool
#  5   window                 117 non-null    float64
#  6   rocket                 205 non-null    object
#  7   success                186 non-null    object
#  8   failures               205 non-null    object
#  9   details                134 non-null    object
#  10  crew                   205 non-null    object
#  11  ships                  205 non-null    object
#  12  capsules               205 non-null    object
#  13  payloads               205 non-null    object
# ...

# %%
df2.columns
# Out:
# RangeIndex(start=0, stop=1, step=1)

# %%
df1_selected = df1[['name','date_utc','rocket','success','launchpad','failures']]
display(df1_selected)
# Out:
#                        name                  date_utc  \
# 0                 FalconSat  2006-03-24T22:30:00.000Z
# 1                   DemoSat  2007-03-21T01:10:00.000Z
# 2               Trailblazer  2008-08-03T03:34:00.000Z
# 3                    RatSat  2008-09-28T23:15:00.000Z
# 4                  RazakSat  2009-07-13T03:35:00.000Z
# ..                      ...                       ...
# 200           Transporter-6  2022-12-01T00:00:00.000Z
# 201                   TTL-1  2022-12-01T00:00:00.000Z
# 202  WorldView Legion 1 & 2  2022-12-01T00:00:00.000Z
# 203     Viasat-3 & Arcturus  2022-12-01T00:00:00.000Z
# 204          O3b mPower 3.4  2022-12-01T00:00:00.000Z
#
#                        rocket success                 launchpad  \
# 0    5e9d0d95eda69955f709d1eb   False  5e9e4502f5090995de566f86
# 1    5e9d0d95eda69955f709d1eb   False  5e9e4502f5090995de566f86
# 2    5e9d0d95eda69955f709d1eb   False  5e9e4502f5090995de566f86
# ...

# %%
url1 = 'https://api.spacexdata.com/v4/rockets'
response = requests.get(url1)
rockets = response.json()

# %%
df2 = pd.DataFrame(rockets)
df2
# Out:
#                           height                        diameter  \
# 0  {'meters': 22.25, 'feet': 73}   {'meters': 1.68, 'feet': 5.5}
# 1  {'meters': 70, 'feet': 229.6}     {'meters': 3.7, 'feet': 12}
# 2  {'meters': 70, 'feet': 229.6}  {'meters': 12.2, 'feet': 39.9}
# 3   {'meters': 118, 'feet': 387}       {'meters': 9, 'feet': 30}
#
#                              mass  \
# 0      {'kg': 30146, 'lb': 66460}
# 1   {'kg': 549054, 'lb': 1207920}
# 2  {'kg': 1420788, 'lb': 3125735}
# 3  {'kg': 1335000, 'lb': 2943000}
#
#                                          first_stage  \
# 0  {'thrust_sea_level': {'kN': 420, 'lbf': 94000}...
# 1  {'thrust_sea_level': {'kN': 7607, 'lbf': 17100...
# 2  {'thrust_sea_level': {'kN': 22819, 'lbf': 5130...
# 3  {'thrust_sea_level': {'kN': 128000, 'lbf': 287...
#
#                                         second_stage  \
# 0  {'thrust': {'kN': 31, 'lbf': 7000}, 'payloads'...
# 1  {'thrust': {'kN': 934, 'lbf': 210000}, 'payloa...
# ...

# %%
df2.columns
# Out:
# Index(['height', 'diameter', 'mass', 'first_stage', 'second_stage', 'engines',
#        'landing_legs', 'payload_weights', 'flickr_images', 'name', 'type',
#        'active', 'stages', 'boosters', 'cost_per_launch', 'success_rate_pct',
#        'first_flight', 'country', 'company', 'wikipedia', 'description', 'id'],
#       dtype='object')

# %%
selected = df2[['name','company','country','cost_per_launch']]
display(selected)
# Out:
#            name company                           country  cost_per_launch
# 0      Falcon 1  SpaceX  Republic of the Marshall Islands          6700000
# 1      Falcon 9  SpaceX                     United States         50000000
# 2  Falcon Heavy  SpaceX                     United States         90000000
# 3      Starship  SpaceX                     United States          7000000

# %%
final = df1_selected.merge(selected,left_on=)
